# %%
import typing
import io
import os, re, glob

import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt

from urllib.request import urlretrieve

from PIL import Image
from torchvision import transforms

from models.modeling import VisionTransformer, CONFIGS

# %% [markdown]
# # Conduct the object detection by Yolov5

# %%
# !cd C:\Users\joechan\Documents\project\AI+ML\image\yolov5
# !del /s /q C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\*.*
# !rmdir /s /q C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result

# !python C:\Users\joechan\Documents\project\AI+ML\image\yolov5\detect.py --source C:\Users\joechan\Documents\project\AI+ML\image\yolov5\data\images\test.jpg --weights C:\Users\joechan\Documents\project\AI+ML\image\yolov5\checkpoints\best.pt --save-crop --name result
# Out:
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\test.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test10.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test11.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test12.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test13.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test14.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test15.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test16.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test17.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test2.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test3.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test4.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test5.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test6.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test7.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test8.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\RBC\test9.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\WBC\test.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\WBC\test2.jpg
# Deleted file - C:\Users\joechan\Documents\project\AI+ML\image\yolov5\runs\detect\result\crops\WBC\test3.jpg
# detect: weights=['C:\\Users\\joechan\\Documents\\project\\AI+ML\\image\\yolov5\\checkpoints\\best.pt'], source=C:\Users\joechan\Documents\project\AI+ML\image\yolov5\data\images\test.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=..\yolov5\runs\detect, name=result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-149-g407a905 torch 1.10.0+cpu CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients
# image 1/1 C:\Users\joechan\Documents\project\AI+ML\image\yolov5\data\images\test.jpg: 384x640 17 RBCs, 3 WBCs, Done. (0.112s)
# Speed: 1.0ms pre-process, 112.0ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ..\yolov5\runs\detect\result

# %%
listing = glob.glob('../yolov5/runs/detect/result/crops/*/*.jpg')
listing
# Out:
# ['../yolov5/runs/detect/result/crops\\RBC\\test.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test10.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test11.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test12.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test13.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test14.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test15.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test16.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test17.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test2.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test3.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test4.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test5.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test6.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test7.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test8.jpg',
#  '../yolov5/runs/detect/result/crops\\RBC\\test9.jpg',
#  '../yolov5/runs/detect/result/crops\\WBC\\test.jpg',
#  '../yolov5/runs/detect/result/crops\\WBC\\test2.jpg',
#  '../yolov5/runs/detect/result/crops\\WBC\\test3.jpg']

# %% [markdown]
# # Define the test input image

# %%
yes_img = "test/test.png"

#yes_img = listing[14]

no_img = "test/no_0012.jpg"

model_path = 'output/test_checkpoint.bin'

# %%
# Prepare Model
config = CONFIGS["ViT-B_16"]
model = VisionTransformer(config, num_classes=2, zero_head=False, img_size=224, vis=True)
checkpoint = torch.load(model_path)
model.load_state_dict(checkpoint)
model.eval()

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])
im = Image.open(yes_img).convert('RGB')
#im = Image.open("test/no_0012.jpg").convert('RGB')
x = transform(im)
x.size()
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# # The Correction Prediction - Demo

# %%
logits, att_mat = model(x.unsqueeze(0))

att_mat = torch.stack(att_mat).squeeze(1)

# Average the attention weights across all heads.
att_mat = torch.mean(att_mat, dim=1)

# To account for residual connections, we add an identity matrix to the
# attention matrix and re-normalize the weights.
residual_att = torch.eye(att_mat.size(1))
aug_att_mat = att_mat + residual_att
aug_att_mat = aug_att_mat / aug_att_mat.sum(dim=-1).unsqueeze(-1)

# Recursively multiply the weight matrices
joint_attentions = torch.zeros(aug_att_mat.size())
joint_attentions[0] = aug_att_mat[0]

for n in range(1, aug_att_mat.size(0)):
    joint_attentions[n] = torch.matmul(aug_att_mat[n], joint_attentions[n-1])
    
# Attention from the output token to the input space.
v = joint_attentions[-1]
grid_size = int(np.sqrt(aug_att_mat.size(-1)))
mask = v[0, 1:].reshape(grid_size, grid_size).detach().numpy()
mask = cv2.resize(mask / mask.max(), im.size)[..., np.newaxis]
result = (mask * im).astype("uint8")

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 16))

ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(im)
_ = ax2.imshow(result)

probs = torch.nn.Softmax(dim=-1)(logits)
pred = torch.argmax(probs, dim=1)
if pred[0] == 1:
    print("yes")
else:
    print("no")
    
probs

# top5 = torch.argsort(probs, dim=-1, descending=True)
# print("Prediction Label and Attention Map!\n")
# for idx in top5[0, :5]:
#     print(f'{probs[0, idx.item()]:.5f} : {imagenet_labels[idx.item()]}', end='')
# Out:
# yes
# tensor([[0.0182, 0.9818]], grad_fn=<SoftmaxBackward0>)

# %%
im = Image.open(no_img).convert('RGB')
x = transform(im)
x.size()

logits, att_mat = model(x.unsqueeze(0))

att_mat = torch.stack(att_mat).squeeze(1)

# Average the attention weights across all heads.
att_mat = torch.mean(att_mat, dim=1)

# To account for residual connections, we add an identity matrix to the
# attention matrix and re-normalize the weights.
residual_att = torch.eye(att_mat.size(1))
aug_att_mat = att_mat + residual_att
aug_att_mat = aug_att_mat / aug_att_mat.sum(dim=-1).unsqueeze(-1)

# Recursively multiply the weight matrices
joint_attentions = torch.zeros(aug_att_mat.size())
joint_attentions[0] = aug_att_mat[0]

for n in range(1, aug_att_mat.size(0)):
    joint_attentions[n] = torch.matmul(aug_att_mat[n], joint_attentions[n-1])
    
# Attention from the output token to the input space.
v = joint_attentions[-1]
grid_size = int(np.sqrt(aug_att_mat.size(-1)))
mask = v[0, 1:].reshape(grid_size, grid_size).detach().numpy()
mask = cv2.resize(mask / mask.max(), im.size)[..., np.newaxis]
result = (mask * im).astype("uint8")

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 16))

ax1.set_title('Original')
ax2.set_title('Attention Map')
_ = ax1.imshow(im)
_ = ax2.imshow(result)

probs = torch.nn.Softmax(dim=-1)(logits)
pred = torch.argmax(probs, dim=1)
if pred[0] == 1:
    print("yes")
else:
    print("no")
    
probs
# top5 = torch.argsort(probs, dim=-1, descending=True)
# print("Prediction Label and Attention Map!\n")
# for idx in top5[0, :5]:
#     print(f'{probs[0, idx.item()]:.5f} : {imagenet_labels[idx.item()]}', end='')
# Out:
# no
# tensor([[9.9999e-01, 7.7915e-06]], grad_fn=<SoftmaxBackward0>)
